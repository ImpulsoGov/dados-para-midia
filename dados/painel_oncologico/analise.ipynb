# %%
import pandas as pd

# %%
df = pd.read_csv("dados_oncologicos_completos.csv")
# Out:
# /var/folders/gy/cxx2_pv95ys52g0qvnjgcsqm0000gn/T/ipykernel_5151/3932395055.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("dados_oncologicos_completos.csv")

# %%
df.head()
# Out:
#   Unnamed: 0  ANO_DIAGN  ANOMES_DIA  ANO_TRATAM  ANOMES_TRA  UF_RESID  \
# 0      1...1       2013      201302      2019.0    201912.0        35
# 1      2...2       2013      201308      2024.0    202408.0        32
# 2      3...3       2013      201309      2017.0    201712.0        35
# 3      4...4       2013      201309      2016.0    201610.0        33
# 4      5...5       2013      201306      2020.0    202003.0        31
#
#    MUN_RESID  UF_TRATAM  MUN_TRATAM  UF_DIAGN  ...  SEXO  ESTADIAM  CNES_DIAG  \
# 0     354780       35.0    355030.0        35  ...     M       5.0    2077531
# 1     320500       32.0    320530.0        32  ...     M       NaN      11738
# 2     355030       35.0    355030.0        35  ...     F       0.0    2077590
# 3     330340       33.0    330580.0        33  ...     M       4.0    2292386
# 4     316720       31.0    310620.0        31  ...     F       2.0    2695324
#
#    CNES_TRAT TEMPO_TRAT  CNS_PAC  DIAG_DETH     DT_DIAG     DT_TRAT  \
# ...

# %%
df['ANO_DIAGN'].unique()
# Out:
# array([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023,
#        2024, 2025])
