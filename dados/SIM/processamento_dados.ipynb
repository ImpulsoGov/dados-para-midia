# %%
import pandas as pd
import os
import glob
import warnings
warnings.filterwarnings("ignore")
# Out:
# /Users/juliasbardelatti/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ### Concatenar dataframes

# %%
caminho_pasta = "./" 
arquivos = glob.glob(os.path.join(caminho_pasta, "*.csv"))

dfs = []

for arquivo in arquivos:
    df = pd.read_csv(arquivo, sep=";", dtype={'DTNASC': str}, encoding="ISO-8859-1")
    df["arquivo_origem"] = os.path.basename(arquivo)  
    dfs.append(df)

df = pd.concat(dfs, ignore_index=True)

print(df.head())
# Out:
#    CONTADOR  ORIGEM  TIPOBITO  DTOBITO HORAOBITO  NATURAL  CODMUNNATU  \
# 0       1.0       1         2  1012016       NaN    812.0    120033.0
# 1       2.0       1         2  1012016       NaN    812.0    120030.0
# 2       3.0       1         2  1012016       NaN    812.0    120030.0
# 3       4.0       1         2  1012016    2100.0      NaN         NaN
# 4       5.0       1         2  1012016    2050.0    812.0    120040.0
#
#      DTNASC  IDADE  SEXO  ...  ALTCAUSA              arquivo_origem  contador  \
# 0  04111988    427     1  ...       NaN  Mortalidade_Geral_2016.csv       NaN
# 1  24112002    413     2  ...       NaN  Mortalidade_Geral_2016.csv       NaN
# 2  04101985    430     1  ...       NaN  Mortalidade_Geral_2016.csv       NaN
# 3  23111959    456     1  ...       NaN  Mortalidade_Geral_2016.csv       NaN
# 4  15122014    401     2  ...       2.0  Mortalidade_Geral_2016.csv       NaN
#
#    OPOR_DO  TP_ALTERA  CB_ALT  CODMUNCART  NUMREGCART  DTREGCART DTRECORIG
# 0      NaN        NaN     NaN         NaN         NaN        NaN       NaN
# 1      NaN        NaN     NaN         NaN         NaN        NaN       NaN
# 2      NaN        NaN     NaN         NaN         NaN        NaN       NaN
# 3      NaN        NaN     NaN         NaN         NaN        NaN       NaN
# 4      NaN        NaN     NaN         NaN         NaN        NaN       NaN
#
# [5 rows x 96 columns]

# %%
df.head()
# Out:
#    CONTADOR  ORIGEM  TIPOBITO  DTOBITO HORAOBITO  NATURAL  CODMUNNATU  \
# 0       1.0       1         2  1012016       NaN    812.0    120033.0
# 1       2.0       1         2  1012016       NaN    812.0    120030.0
# 2       3.0       1         2  1012016       NaN    812.0    120030.0
# 3       4.0       1         2  1012016    2100.0      NaN         NaN
# 4       5.0       1         2  1012016    2050.0    812.0    120040.0
#
#      DTNASC  IDADE  SEXO  ...  ALTCAUSA              arquivo_origem  contador  \
# 0  04111988    427     1  ...       NaN  Mortalidade_Geral_2016.csv       NaN
# 1  24112002    413     2  ...       NaN  Mortalidade_Geral_2016.csv       NaN
# 2  04101985    430     1  ...       NaN  Mortalidade_Geral_2016.csv       NaN
# 3  23111959    456     1  ...       NaN  Mortalidade_Geral_2016.csv       NaN
# 4  15122014    401     2  ...       2.0  Mortalidade_Geral_2016.csv       NaN
#
#    OPOR_DO  TP_ALTERA  CB_ALT  CODMUNCART  NUMREGCART  DTREGCART DTRECORIG
# 0      NaN        NaN     NaN         NaN         NaN        NaN       NaN
# 1      NaN        NaN     NaN         NaN         NaN        NaN       NaN
# 2      NaN        NaN     NaN         NaN         NaN        NaN       NaN
# 3      NaN        NaN     NaN         NaN         NaN        NaN       NaN
# 4      NaN        NaN     NaN         NaN         NaN        NaN       NaN
#
# [5 rows x 96 columns]

# %%
df_2024 = df.query("arquivo_origem == 'DO24OPEN.csv'")
df_2024['DTOBITO'].max()
# Out:
# 31122024

# %%
df = df[df['CAUSABAS'].str.contains('C53', na=False, regex=True)]

# %%
df['DTOBITO'] = df['DTOBITO'].astype(str).str.zfill(8)
df['DTOBITO'] = pd.to_datetime(df['DTOBITO'].astype(str), format='%d%m%Y')
df['DTNASC'] = df['DTNASC'].astype(str).str.zfill(8)
df['DTNASC'] = pd.to_datetime(df['DTNASC'].astype(str), format='%d%m%Y', errors='coerce')
df['ano_obito'] = df['DTOBITO'].dt.year

# %%
print(f"Total casos óbito: {len(df)} - nos anos {df['ano_obito'].unique()}")
# Out:
# Total casos óbito: 76233 - nos anos [2016 2023 2015 2014 2022 2013 2020 2021 2017 2024 2018 2019]

# %%
print(f"Total casos com data nascimento null: {len(df[df['DTNASC'].isna()])}")
# Out:
# Total casos com data nascimento null: 24

# %%
df.to_csv("../../dados_processados_SIM_filtrado.csv")
